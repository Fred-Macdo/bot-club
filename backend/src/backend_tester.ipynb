# %%
import sys
import os

# Make the import root match Docker's layout:
# Docker WORKDIR = /app (which is backend/), and runs "uvicorn src.main:app"
# So we add backend/ to sys.path so "from src.xxx import ..." works identically.
backend_dir = os.path.abspath(os.path.join(os.path.dirname("__file__"), ".."))
if backend_dir not in sys.path:
    sys.path.insert(0, backend_dir)

print(f"Python path root set to: {backend_dir}")
print("Imports now use 'src.' prefix, matching Docker.")
# Out:
# Python path root set to: c:\Users\fwmac\Documents\Projects\Bot-Club\app\backend
# Imports now use 'src.' prefix, matching Docker.

# %%
# Cell 1: Setup and imports
import requests
import json
import time
from datetime import datetime
from pprint import pprint
from src.models.user_config import ConfigEncryption
# Configuration
BASE_URL = "http://localhost:8000"
FRONTEND_URL = "http://localhost:3000"

print("🧪 Bot Club Backtest Integration Test")
print("=" * 50)
# Out:
# 🧪 Bot Club Backtest Integration Test
# ...

# %%
# Cell 2: Test basic connectivity
print("Testing basic connectivity...")

# Test backend health
try:
    response = requests.get(f"{BASE_URL}/health")
    print(f"✅ Backend health: {response.json()}")
except Exception as e:
    print(f"❌ Backend not reachable: {e}")
# Out:
# Testing basic connectivity...
# ✅ Backend health: {'status': 'unhealthy', 'database': 'disconnected', 'error': "object dict can't be used in 'await' expression"}

# %%
# Cell 3: Authentication - Use existing user or create new one
# Option A: Use existing credentials
TEST_USER = {
    "username": "test_user",  # Change to your test user
    "password": "test_user"
}

# Option B: Create new user (uncomment to use)
# TEST_USER = {
#     "userName": f"testuser_{int(time.time())}",
#     "email": f"test_{int(time.time())}@example.com", 
#     "password": "testpass123",
#     "firstName": "Test",
#     "lastName": "User"
# }

print(f"Using credentials: {TEST_USER['username']}")
# Out:
# Using credentials: test_user

# %%
# Cell 4: Login and get token
print("Logging in...")

login_data = {
    "username": TEST_USER["username"],
    "password": TEST_USER["password"]
}

response = requests.post(
    f"{BASE_URL}/api/auth/token",
    data=login_data,  # Form data for OAuth2
    headers={"Content-Type": "application/x-www-form-urlencoded"}
)

if response.status_code == 200:
    token_data = response.json()
    TOKEN = token_data['access_token']
    print(f"✅ Login successful")
    print(f"Token: {TOKEN[:50]}...")
    
    # Set headers for future requests
    headers = {"Authorization": f"Bearer {TOKEN}"}
else:
    print(f"❌ Login failed: {response.status_code}")
    print(response.text)
# Out:
# Logging in...
# ✅ Login successful
# Token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI2O...

# %%
# Cell 5: Get available strategies
print("Fetching strategies...")

# Get default strategies with IDs (this is what the frontend uses)
response = requests.get(f"{BASE_URL}/api/strategy/defaults/with-ids", headers=headers)
print(f"Response status: {response.status_code}")

if response.status_code == 200:
    strategies = response.json()
    print(f"\nFound {len(strategies)} strategies:")
    for s in strategies[:3]:  # Show first 3
        print(f"  - {s['name']} (ID: {s['id']}, Type: {s['type']})")
    
    # Select first strategy
    if strategies:
        STRATEGY_ID = strategies[0]['id']
        print(f"\nSelected strategy ID: {STRATEGY_ID}")
else:
    print(f"Failed to get strategies: {response.text}")
# Out:
# Fetching strategies...
# Response status: 500
# Failed to get strategies: {"detail":"Failed to load default strategies with IDs: 'async for' requires an object with __aiter__ method, got Cursor"}

# %%
# Authenticate and get a fresh JWT token
print("Authenticating...")

login_data = {
    "username": TEST_USER["username"],
    "password": TEST_USER["password"]
}

# Request token
response = requests.post(
    f"{BASE_URL}/api/auth/token",
    data=login_data,
    headers={"Content-Type": "application/x-www-form-urlencoded"}
)

if response.status_code == 200:
    token_data = response.json()
    TOKEN = token_data['access_token']
    
    # Update headers for subsequent requests
    headers = {"Authorization": f"Bearer {TOKEN}"}
    
    print("✅ Authentication successful")
    print(f"Token: {TOKEN[:20]}... (truncated)")
else:
    print(f"❌ Authentication failed: {response.status_code}")
    print(response.text)
# Out:
# Authenticating...
# ✅ Authentication successful
# Token: eyJhbGciOiJIUzI1NiIs... (truncated)

# %%
TOKEN
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI2OTgxMzM4NjQ0Njc0M2IxNjlkNzlkNzEiLCJleHAiOjE3NzIzODkxMjJ9.WTznfqnh0iaBaHzlpM2WkKIVn_uCrlTPHdRDZmWecFg'

# %%
# Cell 6: Test the backtest endpoint
print("Testing backtest endpoint...")

backtest_params = {
    "strategy_id": "6981717773df9d97a3be8bbf",
    "initial_capital": 100000,
    "timeframe": "1d", 
    "start_date": "2023-01-01",
    "end_date": "2023-12-31",
    "data_provider": "alpaca"
}

print("\nRequest parameters:")
pprint(backtest_params)

# Make the request
response = requests.post(
    f"{BASE_URL}/api/backtest/run",
    json=backtest_params,
    headers={
        "Authorization": f"Bearer {TOKEN}",
        "Content-Type": "application/json",
        "Origin": FRONTEND_URL  # Simulate browser request
    }
)

print(f"\nResponse status: {response.status_code}")
print(f"Response headers: {dict(response.headers)}")

if response.status_code == 200:
    result = response.json()
    print(f"✅ Success: {result}")
else:
    print(f"❌ Failed: {response.text}")
    try:
        error = response.json()
        print("Error details:")
        pprint(error)
    except:
        pass
# Out:
# Testing backtest endpoint...
#
# Request parameters:
# {'data_provider': 'alpaca',
#  'end_date': '2023-12-31',
#  'initial_capital': 100000,
#  'start_date': '2023-01-01',
#  'strategy_id': '6981717773df9d97a3be8bbf',
#  'timeframe': '1d'}
#
# Response status: 200
# Response headers: {'date': 'Sun, 01 Mar 2026 17:48:41 GMT', 'server': 'uvicorn', 'content-length': '96', 'content-type': 'application/json', 'access-control-allow-credentials': 'true', 'access-control-expose-headers': '*', 'access-control-allow-origin': 'http://localhost:3000', 'vary': 'Origin'}
# ✅ Success: {'backtest_id': 'a291ca1a-4c19-4088-81a7-ce2ab905f31a', 'message': 'Backtest started successfully'}

# %%
# Cell 7: Test CORS specifically
print("Testing CORS configuration...")

# OPTIONS request (preflight)
response = requests.options(
    f"{BASE_URL}/api/backtest/run",
    headers={
        "Origin": FRONTEND_URL,
        "Access-Control-Request-Method": "POST",
        "Access-Control-Request-Headers": "authorization,content-type"
    }
)

print(f"Preflight status: {response.status_code}")
print("\nCORS headers:")
print(f"  Allow-Origin: {response.headers.get('Access-Control-Allow-Origin', 'NOT SET')}")
print(f"  Allow-Methods: {response.headers.get('Access-Control-Allow-Methods', 'NOT SET')}")
print(f"  Allow-Headers: {response.headers.get('Access-Control-Allow-Headers', 'NOT SET')}")
print(f"  Allow-Credentials: {response.headers.get('Access-Control-Allow-Credentials', 'NOT SET')}")
# Out:
# Testing CORS configuration...
# Preflight status: 200
#
# CORS headers:
#   Allow-Origin: http://localhost:3000
#   Allow-Methods: DELETE, GET, HEAD, OPTIONS, PATCH, POST, PUT
#   Allow-Headers: authorization,content-type
#   Allow-Credentials: true

# %%
import pandas as pd
from IPython.display import display

def get_all_backtests(base_url, headers):
    """Fetch all backtest results and display them in a DataFrame"""
    print("Fetching all backtest results...", f"{base_url}/api/backtest/user")
    
    response = requests.get(
        f"{base_url}/api/backtest/user",
        headers=headers
    )
    
    print(f"Response status: {response.status_code}")
    
    if response.status_code == 200:
        results = response.json()
        if not results:
            print("No backtest results found.")
            return
        
        # Normalize nested JSON data
        df = pd.json_normalize(results, sep='_')
        
        # Select and reorder columns for better readability
        
        with pd.option_context('display.max_rows', None, 'display.max_columns', None):
            display(df)
            
    else:
        print(f"❌ Failed to get backtest results: {response.text}")

# Run the function
get_all_backtests(BASE_URL, headers)
# Out:
# Fetching all backtest results... http://localhost:8000/api/backtest/user
# Response status: 200
# No backtest results found.

# %%
from src.services.data_retrieval.data_manager import DataManager
from datetime import datetime

# %%
keys = requests.get(f"{BASE_URL}/api/user-config", headers=headers).json()

# %%
data_manager = DataManager(keys=keys, provider_name="polygon")
data = await data_manager.fetch_historical_data(
    symbols=["AVAX"],
    start_date=datetime(2025, 1, 1),
    end_date=datetime(2025, 12, 31),
    timeframe="1D"
)

# %%
data
# Out:
# shape: (365, 8)
# ┌─────────────────────────┬───────┬────────┬───────┬────────┬───────────────┬─────────┬────────┐
# │ datetime                ┆ open  ┆ high   ┆ low   ┆ close  ┆ volume        ┆ vwap    ┆ symbol │
# │ ---                     ┆ ---   ┆ ---    ┆ ---   ┆ ---    ┆ ---           ┆ ---     ┆ ---    │
# │ datetime[ms,            ┆ f64   ┆ f64    ┆ f64   ┆ f64    ┆ f64           ┆ f64     ┆ str    │
# │ America/New_York]       ┆       ┆        ┆       ┆        ┆               ┆         ┆        │
# ╞═════════════════════════╪═══════╪════════╪═══════╪════════╪═══════════════╪═════════╪════════╡
# │ 2024-12-31 19:00:00 EST ┆ 35.63 ┆ 38.0   ┆ 34.9  ┆ 37.7   ┆ 342012.376249 ┆ 36.2919 ┆ AVAX   │
# │ 2025-01-01 19:00:00 EST ┆ 37.71 ┆ 40.64  ┆ 37.71 ┆ 39.23  ┆ 636487.996252 ┆ 39.3196 ┆ AVAX   │
# │ 2025-01-02 19:00:00 EST ┆ 39.25 ┆ 42.206 ┆ 38.88 ┆ 41.92  ┆ 1.0333e6      ┆ 40.9834 ┆ AVAX   │
# ...

# %%
STRATEGY_ID = "6981717773df9d97a3be8bbf"

strategy = requests.get(f"{BASE_URL}/api/strategy/{STRATEGY_ID}", headers=headers).json()
strategy
# Out:
# {'_id': '6981717773df9d97a3be8bbf',
#  'user_id': '69813386446743b169d79d71',
#  'name': 'TESTUSERMACDCRYPTO',
#  'description': 'TEST THE NEW USER STRATEGY WITH MACD',
#  'config': {'symbols': ['AVAX'],
#   'timeframe': '2MIN',
#   'start_date': '2024-01-01',
#   'end_date': '2024-12-31',
#   'entry_conditions': [{'indicator': 'macd_line',
#     'comparison': 'crosses_above',
#     'value': 'macd_signal'}],
#   'exit_conditions': [{'indicator': 'macd_line',
#     'comparison': 'crosses_below',
#     'value': 'macd_signal'}],
#   'risk_management': {'position_sizing_method': 'risk_based',
#    'risk_per_trade': 0.02,
#    'stop_loss': 0.05,
#    'take_profit': 0.1,
#    'max_position_size': 10000.0,
#    'atr_multiplier': 2.0},
#   'indicators': [{'name': 'MACD',
#     'params': {'fast': 12, 'slow': 26, 'signal': 9}}],
#   'dollar_cost_average': {'enabled': False,
#    'interval': '1d',
#    'max_attempts': 3,
#    'amount_per_attempt': 100.0}},
#  'is_active': False,
# ...

# %%
from src.utils.strategy_executor import StrategyExecutor
from bson import ObjectId

# %%
strategy_executor = StrategyExecutor(strategy=strategy, data=data, initial_capital=25000.0)

# %%
strategy_executor.strategy['config']['start_date'] = "2025-01-01"
strategy_executor.strategy['config']['end_date'] = "2025-12-31"
strategy_executor.strategy
# Out:
# {'_id': '6981717773df9d97a3be8bbf',
#  'user_id': '69813386446743b169d79d71',
#  'name': 'TESTUSERMACDCRYPTO',
#  'description': 'TEST THE NEW USER STRATEGY WITH MACD',
#  'config': {'symbols': ['AVAX'],
#   'timeframe': '2MIN',
#   'start_date': '2025-01-01',
#   'end_date': '2025-12-31',
#   'entry_conditions': [{'indicator': 'macd_line',
#     'comparison': 'crosses_above',
#     'value': 'macd_signal'}],
#   'exit_conditions': [{'indicator': 'macd_line',
#     'comparison': 'crosses_below',
#     'value': 'macd_signal'}],
#   'risk_management': {'position_sizing_method': 'risk_based',
#    'risk_per_trade': 0.02,
#    'stop_loss': 0.05,
#    'take_profit': 0.1,
#    'max_position_size': 10000.0,
#    'atr_multiplier': 2.0},
#   'indicators': [{'name': 'MACD',
#     'params': {'fast': 12, 'slow': 26, 'signal': 9}}],
#   'dollar_cost_average': {'enabled': False,
#    'interval': '1d',
#    'max_attempts': 3,
#    'amount_per_attempt': 100.0}},
#  'is_active': False,
# ...

# %%
result_portfolio = await strategy_executor.execute_strategy()

# %%
from src.models.portfolio_models import StrategyPortfolio

test_portfolio = StrategyPortfolio(strategy_id=ObjectId(STRATEGY_ID),
                                   user_id=ObjectId(strategy.get("user_id")),
                                   initial_capital=25000.0,
                                   strategy_name="Test Strategy",
                                   performance={},
                                   )

# %%
result_portfolio.get_position_quantity("AAPL")
# Out:
# 0

# %%
strategy_executor.portfolio.model_dump()
# Out:
# {'portfolio_id': 'ccd8ee57-2534-4ad2-9176-b7bea76a0425',
#  'strategy_id': ObjectId('6981717773df9d97a3be8bbf'),
#  'user_id': ObjectId('69813386446743b169d79d71'),
#  'strategy_name': 'TESTUSERMACDCRYPTO',
#  'initial_capital': Decimal('25000.0'),
#  'current_cash': Decimal('24633.26375258771274633940797'),
#  'lots': {},
#  'completed_trades': [{'trade_id': '7422b200-582c-4281-816b-7b7aac4e50ca',
#    'lot_id': 'e00c3a06-37cd-43b7-b412-204843fe96cb',
#    'symbol': 'AVAX',
#    'trade_type': <TradeType.LONG: 'long'>,
#    'quantity': Decimal('18.94657067070860174308450171'),
#    'entry_price': Decimal('26.39'),
#    'entry_time': datetime.datetime(2025, 2, 13, 19, 0, tzinfo=zoneinfo.ZoneInfo(key='America/New_York')),
#    'entry_reason': 'Entry Signal',
#    'exit_price': Decimal('17.96'),
#    'exit_time': datetime.datetime(2025, 3, 8, 19, 0, tzinfo=zoneinfo.ZoneInfo(key='America/New_York')),
#    'exit_reason': 'Exit: macd_line',
# ...

# %%
from src.utils.indicator_factory import IndicatorFactory
from src.utils.indicator_converter import convert_indicators_to_params

# %%
indicator_factory = IndicatorFactory(df=data,
                                     params=convert_indicators_to_params(strategy_executor.strategy['config']['indicators']))

data = indicator_factory.calculate_indicators()

# %%
import matplotlib.pyplot as plt
import polars as pl

symbols = data['symbol'].unique().to_list()
num_symbols = len(symbols)

fig, axes = plt.subplots(1, num_symbols, figsize=(14, 7), squeeze=False)

for i, symbol in enumerate(symbols):
    ax = axes[0][i]
    symbol_data = data.filter(pl.col('symbol') == symbol).sort('datetime')
    
    if symbol_data.is_empty():
        ax.set_title(f'{symbol} - No data')
        continue
    
    # Convert to Python lists for matplotlib
    dates = symbol_data['datetime'].to_list()
    #close = symbol_data['close'].to_list()
    
    ax.plot(dates, symbol_data['macd_line'], label='macd_line', alpha=0.7)
    
    # Dynamically find and plot indicator columns (ema_*, sma_*)
    for col in symbol_data.columns:
        col_lower = col.lower()
        if not col_lower.endswith('_prev'):
            if col_lower.startswith('ema') or col_lower.startswith('sma'):
                values = symbol_data[col].to_list()
                # Skip if all nulls
                if any(v is not None for v in values):
                    ax.plot(dates, values, label=col, linewidth=1.5)
            elif col_lower.startswith('rsi'):
                values = symbol_data[col].to_list()
                if any(v is not None for v in values):
                    ax.plot(dates, values, label=col, linewidth=1.5)
            elif col_lower.startswith('macd'):
                values = symbol_data[col].to_list()
                if any(v is not None for v in values):
                    ax.plot(dates, values, label=col, linewidth=1.5)
            elif col_lower.startswith('upper_band') or col_lower.startswith('lower_band'):
                values = symbol_data[col].to_list()
                if any(v is not None for v in values):
                    ax.plot(dates, values, label=col, linewidth=1.5)
            elif col_lower.startswith('mfi'):
                values = symbol_data[col].to_list()
                if any(v is not None for v in values):
                    ax.plot(dates, values, label=col, linewidth=1.5)
    
    ax.set_title(f'{symbol}')
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    ax.legend()
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
len(result_portfolio.equity_curve)
# Out:
# 365

# %%
result_portfolio.performance
# Out:
# PerformanceMetrics(total_trades=14, winning_trades=3, losing_trades=11, win_rate=21.428571428571427, total_pnl=Decimal('-366.7362474122872536605920234'), total_pnl_pct=-1.466944989649149, avg_win=Decimal('92.83407782413892033110962177'), avg_loss=Decimal('-58.65804371679127405944735352'), largest_win=Decimal('175.6843510015147073819070899'), largest_loss=Decimal('-159.7195907540735126942023494'), sharpe_ratio=None, max_drawdown=1.6033810575605236, max_drawdown_duration_days=None, avg_holding_period_days=13.071428571428571, max_concurrent_positions=0, total_dca_entries=0, avg_lots_per_position=0.0, calculated_at=datetime.datetime(2026, 3, 1, 17, 48, 47, 20531))

# %%
strategy_executor.trade_logger.print_trade_summary()

# %%
no_data_strategy = StrategyExecutor(strategy=strategy,
                                    initial_capital=10000,
                                    encrypted_keys=keys,
                                    data_provider="alpaca")

no_data_strategy.data

# %%
no_data_executor = await no_data_strategy.execute_strategy()

# %%
no_data_executor.completed_trades
# Out:
# [CompletedTrade(trade_id='b981f6c6-39cb-412e-9eec-c21920959d11', lot_id='001b28bc-437d-4dd6-8485-7a91e0bd14b0', symbol='AVAX', trade_type=<TradeType.LONG: 'long'>, quantity=Decimal('7.572889057175312381673608482'), entry_price=Decimal('26.41'), entry_time=datetime.datetime(2025, 2, 14, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), entry_reason='Entry Signal', exit_price=Decimal('17.9485'), exit_time=datetime.datetime(2025, 3, 9, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), exit_reason='Exit: macd_line', realized_pnl=Decimal('-64.07800075728890571753123817'), realized_pnl_pct=-32.03900037864445, strategy_id='6981717773df9d97a3be8bbf', user_id='69813386446743b169d79d71', entry_order_id=None, exit_order_id=None, lot_selection_method='fifo', holding_period_days=23, commission=Decimal('0')),
# ...

# %%
from src.tasks.backtest_task import _run_backtest_pipeline, _save_backtest_results, _save_backtest_error
import celery

# %%
import uuid

payload = {
    "backtest_id": str(uuid.uuid4()),
    "strategy_id": STRATEGY_ID,
    "user_id": strategy.get("user_id"),
    "strategy_config": strategy,
    "initial_capital": 25000.0,
    "timeframe": "1D",
    "start_date": "2025-01-01",
    "end_date": "2025-12-31",
    "data_provider": "polygon",
    "encrypted_keys": keys
}

# Call the async pipeline directly (no Celery in notebook)
result = await _run_backtest_pipeline(payload)
print(f"Backtest complete: {result}")
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
result
